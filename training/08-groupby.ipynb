# %%
import pandas as pd

# %%
df = pd.read_csv('../data/gapminder.tsv', sep='\t')

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df2 = df.copy()

# %%
df2['normalized_lifeExp'] = df2.groupby('year')['lifeExp'].transform(lambda x: (x - x.mean()) / x.std())

# %%
df2
# Out:
#           country continent  year  lifeExp       pop   gdpPercap  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
#       normalized_lifeExp
# 0              -1.656854
# 1              -1.731249
# 2              -1.786543
# 3              -1.848157
# 4              -1.894173
# ...                  ...
# ...

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby('size').count()
# Out:
#       total_bill  tip  sex  smoker  day  time
# size
# 1              4    4    4       4    4     4
# 2            156  156  156     156  156   156
# 3             38   38   38      38   38    38
# 4             37   37   37      37   37    37
# 5              5    5    5       5    5     5
# 6              4    4    4       4    4     4

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
tips_10 = sns.load_dataset('tips').sample(10, random_state=42)
grouped = tips_10.groupby('sex')
grouped

# %%
grouped.groups
# Out:
# {'Male': [24, 6, 153, 211, 176, 192, 9], 'Female': [198, 124, 101]}

# %%
tips_10
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 153       24.55  2.00    Male     No   Sun  Dinner     4
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2
# 124       12.48  2.52  Female     No  Thur   Lunch     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2

# %%
group_avg = tips_10.groupby(['sex', 'time']).mean()
# Out:
# C:\Users\chfal\AppData\Local\Temp\ipykernel_13996\2984618912.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_avg = tips_10.groupby(['sex', 'time']).mean()

# %%
group_avg
# Out:
#                total_bill       tip      size
# sex    time
# Male   Lunch    28.440000  2.560000  2.000000
#        Dinner   18.616667  2.928333  2.666667
# Female Lunch    12.740000  2.260000  2.000000
#        Dinner   15.380000  3.000000  2.000000

# %%
intv_df = pd.read_csv(r'../data/epi_sim.zip')

# %%
intv_df.head()
# Out:
#    ig_type  intervened        pid  rep  sid        tr
# 0        3          40  294524448    1  201  0.000135
# 1        3          40  294571037    1  201  0.000135
# 2        3          40  290699504    1  201  0.000135
# 3        3          40  288354895    1  201  0.000135
# 4        3          40  292271290    1  201  0.000135

# %%
count_only = (
  intv_df
  .groupby(["rep", "intervened", "tr"])
  ["ig_type"]
  .count()
)

# %%
type(count_only)
# Out:
# pandas.core.series.Series

# %%
count_only
# Out:
# rep  intervened  tr
# 0    8           0.000166    1
#      9           0.000152    3
#                  0.000166    1
#      10          0.000152    1
#                  0.000166    1
#                             ..
# 2    193         0.000135    1
#                  0.000152    1
#      195         0.000135    1
#      198         0.000166    1
#      199         0.000135    1
# Name: ig_type, Length: 1196, dtype: int64
